# %%
from parler_tts import ParlerTTSForConditionalGeneration
from transformers import AutoTokenizer

model = ParlerTTSForConditionalGeneration.from_pretrained("ai4bharat/indic-parler-tts")
tokenizer = AutoTokenizer.from_pretrained("ai4bharat/indic-parler-tts")
print("✅ All compatible versions loaded!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\shrut\anaconda3\envs\indicf5\lib\site-packages\transformers\utils\import_utils.py:1472, in _get_module(self, module_name)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\shrut\anaconda3\envs\indicf5\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\shrut\anaconda3\envs\indicf5\lib\site-packages\transformers\generation\utils.py:28
#      26 from torch.nn import functional as F
# ---> 28 from ..cache_utils import (
#      29     Cache,
#      30     DynamicCache,
#      31     EncoderDecoderCache,
#      32     OffloadedCache,
#      33     QuantizedCacheConfig,
#      34     StaticCache,
#      35 )
#      36 from ..configuration_utils import PretrainedConfig
#
# ImportError: cannot import name 'EncoderDecoderCache' from 'transformers.cache_utils' (c:\Users\shrut\anaconda3\envs\indicf5\lib\site-packages\transformers\cache_utils.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\shrut\anaconda3\envs\indicf5\lib\site-packages\transformers\utils\import_utils.py:1472, in _get_module(self, module_name)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\shrut\anaconda3\envs\indicf5\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\shrut\anaconda3\envs\indicf5\lib\site-packages\transformers\modeling_utils.py:46
#      45 from .dynamic_module_utils import custom_object_save
# ---> 46 from .generation import GenerationConfig, GenerationMixin
#      47 from .integrations import PeftAdapterMixin, deepspeed_config, is_deepspeed_zero3_enabled
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\shrut\anaconda3\envs\indicf5\lib\site-packages\transformers\utils\import_utils.py:1462, in __getattr__(self, name)
#    1460 # docstyle-ignore
#    1461 SCIPY_IMPORT_ERROR = """
# -> 1462 {0} requires the scipy library but it was not found in your environment. You can install it with pip:
#    1463 `pip install scipy`. Please note that you may need to restart your runtime after installation.
#    1464 """
#    1467 # docstyle-ignore
#
# File c:\Users\shrut\anaconda3\envs\indicf5\lib\site-packages\transformers\utils\import_utils.py:1474, in _get_module(self, module_name)
#    1473 # docstyle-ignore
# -> 1474 TIMM_IMPORT_ERROR = """
#    1475 {0} requires the timm library but it was not found in your environment. You can install it with pip:
#    1476 `pip install timm`. Please note that you may need to restart your runtime after installation.
#    1477 """
#    1479 # docstyle-ignore
#
# RuntimeError: Failed to import transformers.generation.utils because of the following error (look up to see its traceback):
# cannot import name 'EncoderDecoderCache' from 'transformers.cache_utils' (c:\Users\shrut\anaconda3\envs\indicf5\lib\site-packages\transformers\cache_utils.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from parler_tts import ParlerTTSForConditionalGeneration
#       2 from transformers import AutoTokenizer
#       4 model = ParlerTTSForConditionalGeneration.from_pretrained("ai4bharat/indic-parler-tts")
#
# File c:\Users\shrut\anaconda3\envs\indicf5\lib\site-packages\parler_tts\__init__.py:7
#       4 from transformers import AutoConfig, AutoModel
#       6 from .configuration_parler_tts import ParlerTTSConfig, ParlerTTSDecoderConfig
# ----> 7 from .dac_wrapper import DACConfig, DACModel
#       8 from .modeling_parler_tts import (
#       9     ParlerTTSForCausalLM,
#      10     ParlerTTSForConditionalGeneration,
#      11     apply_delay_pattern_mask,
#      12     build_delay_pattern_mask,
#      13 )
#      15 from .streamer import ParlerTTSStreamer
#
# File c:\Users\shrut\anaconda3\envs\indicf5\lib\site-packages\parler_tts\dac_wrapper\__init__.py:2
#       1 from .configuration_dac import DACConfig
# ----> 2 from .modeling_dac import DACModel
#
# File c:\Users\shrut\anaconda3\envs\indicf5\lib\site-packages\parler_tts\dac_wrapper\modeling_dac.py:5
#       2 from dac.model import DAC
#       3 from torch import nn
# ----> 5 from transformers import PreTrainedModel
#       6 from transformers.models.encodec.modeling_encodec import EncodecDecoderOutput, EncodecEncoderOutput
#       8 from .configuration_dac import DACConfig
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\shrut\anaconda3\envs\indicf5\lib\site-packages\transformers\utils\import_utils.py:1462, in __getattr__(self, name)
#    1455 SACREMOSES_IMPORT_ERROR = """
#    1456 {0} requires the sacremoses library but it was not found in your environment. You can install it with pip:
#    1457 `pip install sacremoses`. Please note that you may need to restart your runtime after installation.
#    1458 """
#    1460 # docstyle-ignore
#    1461 SCIPY_IMPORT_ERROR = """
# -> 1462 {0} requires the scipy library but it was not found in your environment. You can install it with pip:
#    1463 `pip install scipy`. Please note that you may need to restart your runtime after installation.
#    1464 """
#    1467 # docstyle-ignore
#    1468 SPEECH_IMPORT_ERROR = """
#    1469 {0} requires the torchaudio library but it was not found in your environment. You can install it with pip:
#    1470 `pip install torchaudio`. Please note that you may need to restart your runtime after installation.
#    1471 """
#
# File c:\Users\shrut\anaconda3\envs\indicf5\lib\site-packages\transformers\utils\import_utils.py:1474, in _get_module(self, module_name)
#    1468 SPEECH_IMPORT_ERROR = """
#    1469 {0} requires the torchaudio library but it was not found in your environment. You can install it with pip:
#    1470 `pip install torchaudio`. Please note that you may need to restart your runtime after installation.
#    1471 """
#    1473 # docstyle-ignore
# -> 1474 TIMM_IMPORT_ERROR = """
#    1475 {0} requires the timm library but it was not found in your environment. You can install it with pip:
#    1476 `pip install timm`. Please note that you may need to restart your runtime after installation.
#    1477 """
#    1479 # docstyle-ignore
#    1480 NATTEN_IMPORT_ERROR = """
#    1481 {0} requires the natten library but it was not found in your environment. You can install it by referring to:
#    1482 shi-labs.com/natten . You can also install it with pip (may take longer to build):
#    1483 `pip install natten`. Please note that you may need to restart your runtime after installation.
#    1484 """
#
# RuntimeError: Failed to import transformers.modeling_utils because of the following error (look up to see its traceback):
# Failed to import transformers.generation.utils because of the following error (look up to see its traceback):
# cannot import name 'EncoderDecoderCache' from 'transformers.cache_utils' (c:\Users\shrut\anaconda3\envs\indicf5\lib\site-packages\transformers\cache_utils.py)
